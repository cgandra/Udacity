# %% [markdown]
# # Navigation
#
# ---
#
# In this notebook, you will learn how to use the Unity ML-Agents environment for the first project of the [Deep Reinforcement Learning Nanodegree](https://www.udacity.com/course/deep-reinforcement-learning-nanodegree--nd893).
#
#
# You are welcome to use this coding environment to train your agent for the project.  Follow the instructions below to get started!
#
# ### 1. Start the Environment
#
# Run the next code cell to install a few packages.  This line will take a few minutes to run!
#
# We begin by importing some necessary packages.  If the code cell below returns an error, please revisit the project instructions to double-check that you have installed [Unity ML-Agents](https://github.com/Unity-Technologies/ml-agents/blob/master/docs/Installation.md) and [NumPy](http://www.numpy.org/).

# %%
# !pip -q install ./python
# Out:
# ipython 6.5.0 has requirement prompt-toolkit<2.0.0,>=1.0.15, but you'll have prompt-toolkit 3.0.3 which is incompatible.

# %%
import numpy as np
import random
from unityagents import UnityEnvironment
from utils import *

# %% [markdown]
# Next, we will start the environment!  **_Before running the code cell below_**, change the `file_name` parameter to match the location of the Unity environment that you downloaded.
#
# - **Mac**: `"path/to/Banana.app"`
# - **Windows** (x86): `"path/to/Banana_Windows_x86/Banana.exe"`
# - **Windows** (x86_64): `"path/to/Banana_Windows_x86_64/Banana.exe"`
# - **Linux** (x86): `"path/to/Banana_Linux/Banana.x86"`
# - **Linux** (x86_64): `"path/to/Banana_Linux/Banana.x86_64"`
# - **Linux** (x86, headless): `"path/to/Banana_Linux_NoVis/Banana.x86"`
# - **Linux** (x86_64, headless): `"path/to/Banana_Linux_NoVis/Banana.x86_64"`
#
# For instance, if you are using a Mac, then you downloaded `Banana.app`.  If this file is in the same folder as the notebook, then the line below should appear as follows:
# ```
# env = UnityEnvironment(file_name="Banana.app")
# ```

# %%
# please do not modify the line below
env = UnityEnvironment(file_name="/data/Banana_Linux_NoVis/Banana.x86_64", seed=0)
# Out:
# INFO:unityagents:
# 'Academy' started successfully!
# Unity Academy name: Academy
#         Number of Brains: 1
#         Number of External Brains : 1
#         Lesson number : 0
#         Reset Parameters :
#
# Unity brain name: BananaBrain
#         Number of Visual Observations (per agent): 0
#         Vector Observation space type: continuous
#         Vector Observation space size (per agent): 37
#         Number of stacked Vector Observation: 1
#         Vector Action space type: discrete
#         Vector Action space size (per agent): 4
#         Vector Action descriptions: , , ,

# %% [markdown]
# Environments contain **_brains_** which are responsible for deciding the actions of their associated agents. Here we check for the first brain available, and set it as the default brain we will be controlling from Python.

# %%
# get the default brain
brain_name = env.brain_names[0]
brain = env.brains[brain_name]

# %% [markdown]
# ### 2. Examine the State and Action Spaces
#
# The simulation contains a single agent that navigates a large environment.  At each time step, it has four actions at its disposal:
# - `0` - walk forward
# - `1` - walk backward
# - `2` - turn left
# - `3` - turn right
#
# The state space has `37` dimensions and contains the agent's velocity, along with ray-based perception of objects around agent's forward direction.  A reward of `+1` is provided for collecting a yellow banana, and a reward of `-1` is provided for collecting a blue banana.
#
# Run the code cell below to print some information about the environment.

# %%
# reset the environment
env_info = env.reset(train_mode=True)[brain_name]

# number of agents in the environment
print('Number of agents:', len(env_info.agents))

# number of actions
action_size = brain.vector_action_space_size
print('Number of actions:', action_size)

# examine the state space 
state = env_info.vector_observations[0]
print('States look like:', state)
state_size = len(state)
print('States have length:', state_size)
#state = np.expand_dims(state, 0)
#state_size = state.shape
#print('States have length:', state_size)
# Out:
# Number of agents: 1
# Number of actions: 4
# States look like: [1.         0.         0.         0.         0.84408134 0.
#  0.         1.         0.         0.0748472  0.         1.
#  0.         0.         0.25755    1.         0.         0.
#  0.         0.74177343 0.         1.         0.         0.
#  0.25854847 0.         0.         1.         0.         0.09355672
#  0.         1.         0.         0.         0.31969345 0.
#  0.        ]
# States have length: 37

# %% [markdown]
# ### 3. Take Random Actions in the Environment
#
# In the next code cell, you will learn how to use the Python API to control the agent and receive feedback from the environment.
#
# Once this cell is executed, you will watch the agent's performance, if it selects an action (uniformly) at random with each time step.  A window should pop up that allows you to observe the agent, as it moves through the environment.
#
# Of course, as part of the project, you'll have to change the code so that the agent is able to use its experience to gradually choose better actions when interacting with the environment!

# %%
env_info = env.reset(train_mode=False)[brain_name] # reset the environment
state = env_info.vector_observations[0]            # get the current state
score = 0                                          # initialize the score
while True:
    action = np.random.randint(action_size)        # select an action
    env_info = env.step(action)[brain_name]        # send the action to the environment
    next_state = env_info.vector_observations[0]   # get the next state
    reward = env_info.rewards[0]                   # get the reward
    done = env_info.local_done[0]                  # see if episode has finished
    score += reward                                # update the score
    state = next_state                             # roll over the state to next time step
    if done:                                       # exit loop if episode finished
        break
    
print("Score: {}".format(score))
# Out:
# Score: 0.0

# %% [markdown]
# When finished, you can close the environment.

# %% [markdown]
# ### 4. It's Your Turn!
#
# Now it's your turn to train your own agent to solve the environment!  When training the environment, set `train_mode=True`, so that the line for resetting the environment looks like the following:
# ```python
# env_info = env.reset(train_mode=True)[brain_name]
# ```

# %%
from utils import *
from workspace_utils import active_session
# %matplotlib inline

eps_decay = [0.995]
a_double = [True, False, True, False]
a_duel = [True, True, False, False]

with active_session():
    run_option('train', eps_decay, a_double, a_duel, 0, moving_avg_tgt=17.0, n_episodes=2000)
# Out:
# INFO:unityagents:
# 'Academy' started successfully!
# Unity Academy name: Academy
#         Number of Brains: 1
#         Number of External Brains : 1
#         Lesson number : 0
#         Reset Parameters :
#
# Unity brain name: BananaBrain
#         Number of Visual Observations (per agent): 0
#         Vector Observation space type: continuous
#         Vector Observation space size (per agent): 37
#         Number of stacked Vector Observation: 1
#         Vector Action space type: discrete
#         Vector Action space size (per agent): 4
#         Vector Action descriptions: , , ,
# <class 'config.AgentConfig'>: {'state_size': 37, 'action_size': 4, 'state_augment_size': 0, 'input_gray': False, 'n_episodes': 2000, 'max_t_steps': 1000, 'replay_buf_size': 100000, 'min_replay_buf_size': 64, 'minibatch_size': 64, 'training_freq': 4, 'update_tgt_freq': 4, 'tau': 0.001, 'gamma': 0.99, 'eps_schedule': 'geometric', 'eps_start': 1.0, 'eps_end': 0.01, 'eps_decay': 0.995, 'seed': 0, 'ckpt_path': None, 'replay_path': None}
# <class 'config.ModelConfig'>: {'learning_rate': 0.0001, 'weight_decay': 0, 'double_dqn': True, 'dueling_dqn': True, 'conv': <ConvType.CONV1D: (0,)>, 'input_dim': 37, 'output_dim': 4, 'seed': 0}
# FcModel(
#   (conv): Sequential(
#     (0): Linear(in_features=37, out_features=64, bias=True)
#     (1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Linear(in_features=64, out_features=64, bias=True)
#     (4): ReLU()
#   )
#   (fc3): Linear(in_features=64, out_features=4, bias=True)
#   (fc3_value): Linear(in_features=64, out_features=1, bias=True)
# )
# FcModel(
#   (conv): Sequential(
#     (0): Linear(in_features=37, out_features=64, bias=True)
#     (1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Linear(in_features=64, out_features=64, bias=True)
#     (4): ReLU()
#   )
#   (fc3): Linear(in_features=64, out_features=4, bias=True)
#   (fc3_value): Linear(in_features=64, out_features=1, bias=True)
# )
# Episode   50, Average Score: -0.24, Best Average Score:  0.67 @ Episode    3, Best Score:  2 @ Episode   43
# Episode  100, Average Score:  0.08, Best Average Score:  0.67 @ Episode    3, Best Score:  4 @ Episode   76
# Episode  150, Average Score:  1.17, Best Average Score:  1.17 @ Episode  150, Best Score:  7 @ Episode  129
# Episode  200, Average Score:  3.34, Best Average Score:  3.34 @ Episode  200, Best Score: 12 @ Episode  199
# Episode  250, Average Score:  5.44, Best Average Score:  5.44 @ Episode  250, Best Score: 12 @ Episode  211
# Episode  300, Average Score:  7.09, Best Average Score:  7.17 @ Episode  297, Best Score: 14 @ Episode  269
# Episode  350, Average Score:  9.18, Best Average Score:  9.18 @ Episode  350, Best Score: 19 @ Episode  343
# Episode  400, Average Score: 10.57, Best Average Score: 10.64 @ Episode  398, Best Score: 20 @ Episode  393
# Episode  450, Average Score: 11.54, Best Average Score: 11.61 @ Episode  447, Best Score: 20 @ Episode  433
# Episode  500, Average Score: 12.48, Best Average Score: 12.48 @ Episode  500, Best Score: 20 @ Episode  493
# Episode  550, Average Score: 13.27, Best Average Score: 13.27 @ Episode  550, Best Score: 25 @ Episode  533
# Episode  600, Average Score: 14.27, Best Average Score: 14.32 @ Episode  599, Best Score: 25 @ Episode  533
# Episode  650, Average Score: 15.18, Best Average Score: 15.54 @ Episode  643, Best Score: 25 @ Episode  636
# Episode  700, Average Score: 15.85, Best Average Score: 15.86 @ Episode  698, Best Score: 25 @ Episode  636
# Episode  750, Average Score: 16.41, Best Average Score: 16.41 @ Episode  750, Best Score: 25 @ Episode  636
# Episode  800, Average Score: 16.86, Best Average Score: 16.88 @ Episode  799, Best Score: 25 @ Episode  636
# Episode  805, Average Score: 17.02, Best Average Score: 17.02 @ Episode  805, Best Score: 25 @ Episode  636
# Environment solved in 705 episodes!, Average Score: 17.02, Best Average Score: 17.02 @ Episode  805, Best Score: 25 @ Episode  636
# Total Training time = 19.1 min for duel_ddqn, eps_decay 0.995
# <class 'config.AgentConfig'>: {'state_size': 37, 'action_size': 4, 'state_augment_size': 0, 'input_gray': False, 'n_episodes': 2000, 'max_t_steps': 1000, 'replay_buf_size': 100000, 'min_replay_buf_size': 64, 'minibatch_size': 64, 'training_freq': 4, 'update_tgt_freq': 4, 'tau': 0.001, 'gamma': 0.99, 'eps_schedule': 'geometric', 'eps_start': 1.0, 'eps_end': 0.01, 'eps_decay': 0.995, 'seed': 0, 'ckpt_path': None, 'replay_path': None}
# <class 'config.ModelConfig'>: {'learning_rate': 0.0001, 'weight_decay': 0, 'double_dqn': False, 'dueling_dqn': True, 'conv': <ConvType.CONV1D: (0,)>, 'input_dim': 37, 'output_dim': 4, 'seed': 0}
# FcModel(
#   (conv): Sequential(
#     (0): Linear(in_features=37, out_features=64, bias=True)
#     (1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Linear(in_features=64, out_features=64, bias=True)
#     (4): ReLU()
#   )
#   (fc3): Linear(in_features=64, out_features=4, bias=True)
#   (fc3_value): Linear(in_features=64, out_features=1, bias=True)
# )
# FcModel(
#   (conv): Sequential(
#     (0): Linear(in_features=37, out_features=64, bias=True)
#     (1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Linear(in_features=64, out_features=64, bias=True)
#     (4): ReLU()
#   )
#   (fc3): Linear(in_features=64, out_features=4, bias=True)
#   (fc3_value): Linear(in_features=64, out_features=1, bias=True)
# )
# Episode  700, Average Score: 15.32, Best Average Score: 15.62 @ Episode  686, Best Score: 23 @ Episode  587
# Episode  750, Average Score: 15.07, Best Average Score: 15.62 @ Episode  686, Best Score: 23 @ Episode  747
# Episode  800, Average Score: 15.68, Best Average Score: 15.68 @ Episode  800, Best Score: 24 @ Episode  767
# Episode  850, Average Score: 16.53, Best Average Score: 16.53 @ Episode  850, Best Score: 25 @ Episode  824
# Episode  900, Average Score: 16.48, Best Average Score: 16.72 @ Episode  886, Best Score: 25 @ Episode  824
# Episode  950, Average Score: 16.27, Best Average Score: 16.72 @ Episode  886, Best Score: 25 @ Episode  824
# Episode 1000, Average Score: 16.65, Best Average Score: 16.72 @ Episode  886, Best Score: 25 @ Episode  824
# Episode 1019, Average Score: 17.07, Best Average Score: 17.07 @ Episode 1019, Best Score: 25 @ Episode  824
# Environment solved in 919 episodes!, Average Score: 17.07, Best Average Score: 17.07 @ Episode 1019, Best Score: 25 @ Episode  824
# Total Training time = 21.7 min for dqn, eps_decay 0.995

# %%
from utils import *
from workspace_utils import active_session
# %matplotlib inline

eps_decay = [0.995]
a_double = [True, False, True, False]
a_duel = [True, True, False, False]

with active_session():
    run_option('test', eps_decay, a_double, a_duel, 0, n_episodes=100, chkpt_type='best_ma')
# Out:
# INFO:unityagents:
# 'Academy' started successfully!
# Unity Academy name: Academy
#         Number of Brains: 1
#         Number of External Brains : 1
#         Lesson number : 0
#         Reset Parameters :
#
# Unity brain name: BananaBrain
#         Number of Visual Observations (per agent): 0
#         Vector Observation space type: continuous
#         Vector Observation space size (per agent): 37
#         Number of stacked Vector Observation: 1
#         Vector Action space type: discrete
#         Vector Action space size (per agent): 4
#         Vector Action descriptions: , , ,
# <class 'config.AgentConfig'>: {'state_size': 37, 'action_size': 4, 'state_augment_size': 0, 'input_gray': False, 'n_episodes': 100, 'max_t_steps': 1000, 'replay_buf_size': 100000, 'min_replay_buf_size': 64, 'minibatch_size': 64, 'training_freq': 4, 'update_tgt_freq': 4, 'tau': 0.001, 'gamma': 0.99, 'eps_schedule': 'geometric', 'eps_start': 1.0, 'eps_end': 0.01, 'eps_decay': 0.995, 'seed': 0, 'ckpt_path': 'results/best_ma_chkpt_0.pth', 'replay_path': None}
# <class 'config.ModelConfig'>: {'learning_rate': 0.0001, 'weight_decay': 0, 'double_dqn': True, 'dueling_dqn': True, 'conv': <ConvType.CONV1D: (0,)>, 'input_dim': 37, 'output_dim': 4, 'seed': 0}
# FcModel(
#   (conv): Sequential(
#     (0): Linear(in_features=37, out_features=64, bias=True)
#     (1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Linear(in_features=64, out_features=64, bias=True)
#     (4): ReLU()
#   )
#   (fc3): Linear(in_features=64, out_features=4, bias=True)
#   (fc3_value): Linear(in_features=64, out_features=1, bias=True)
# )
# FcModel(
#   (conv): Sequential(
#     (0): Linear(in_features=37, out_features=64, bias=True)
#     (1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Linear(in_features=64, out_features=64, bias=True)
#     (4): ReLU()
#   )
#   (fc3): Linear(in_features=64, out_features=4, bias=True)
#   (fc3_value): Linear(in_features=64, out_features=1, bias=True)
# )
# load episode: 805
# Episode  100, Average Score: 16.60, Best Average Score: 19.00 @ Episode    1, Best Score: 24 @ Episode   57
# <class 'config.AgentConfig'>: {'state_size': 37, 'action_size': 4, 'state_augment_size': 0, 'input_gray': False, 'n_episodes': 100, 'max_t_steps': 1000, 'replay_buf_size': 100000, 'min_replay_buf_size': 64, 'minibatch_size': 64, 'training_freq': 4, 'update_tgt_freq': 4, 'tau': 0.001, 'gamma': 0.99, 'eps_schedule': 'geometric', 'eps_start': 1.0, 'eps_end': 0.01, 'eps_decay': 0.995, 'seed': 0, 'ckpt_path': 'results/best_ma_chkpt_1.pth', 'replay_path': None}
# <class 'config.ModelConfig'>: {'learning_rate': 0.0001, 'weight_decay': 0, 'double_dqn': False, 'dueling_dqn': True, 'conv': <ConvType.CONV1D: (0,)>, 'input_dim': 37, 'output_dim': 4, 'seed': 0}
# FcModel(
#   (conv): Sequential(
#     (0): Linear(in_features=37, out_features=64, bias=True)
#     (1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Linear(in_features=64, out_features=64, bias=True)
#     (4): ReLU()
#   )
#   (fc3): Linear(in_features=64, out_features=4, bias=True)
#   (fc3_value): Linear(in_features=64, out_features=1, bias=True)
# )
# FcModel(
#   (conv): Sequential(
#     (0): Linear(in_features=37, out_features=64, bias=True)
#     (1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Linear(in_features=64, out_features=64, bias=True)
#     (4): ReLU()
#   )
#   (fc3): Linear(in_features=64, out_features=4, bias=True)
#   (fc3_value): Linear(in_features=64, out_features=1, bias=True)
# )
# load episode: 1231
# Episode  100, Average Score: 16.20, Best Average Score: 16.93 @ Episode   61, Best Score: 23 @ Episode   29
# <class 'config.AgentConfig'>: {'state_size': 37, 'action_size': 4, 'state_augment_size': 0, 'input_gray': False, 'n_episodes': 100, 'max_t_steps': 1000, 'replay_buf_size': 100000, 'min_replay_buf_size': 64, 'minibatch_size': 64, 'training_freq': 4, 'update_tgt_freq': 4, 'tau': 0.001, 'gamma': 0.99, 'eps_schedule': 'geometric', 'eps_start': 1.0, 'eps_end': 0.01, 'eps_decay': 0.995, 'seed': 0, 'ckpt_path': 'results/best_ma_chkpt_2.pth', 'replay_path': None}
# <class 'config.ModelConfig'>: {'learning_rate': 0.0001, 'weight_decay': 0, 'double_dqn': True, 'dueling_dqn': False, 'conv': <ConvType.CONV1D: (0,)>, 'input_dim': 37, 'output_dim': 4, 'seed': 0}
# FcModel(
#   (conv): Sequential(
#     (0): Linear(in_features=37, out_features=64, bias=True)
#     (1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Linear(in_features=64, out_features=64, bias=True)
#     (4): ReLU()
#   )
#   (fc3): Linear(in_features=64, out_features=4, bias=True)
# )
# FcModel(
#   (conv): Sequential(
#     (0): Linear(in_features=37, out_features=64, bias=True)
#     (1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Linear(in_features=64, out_features=64, bias=True)
#     (4): ReLU()
#   )
#   (fc3): Linear(in_features=64, out_features=4, bias=True)
# )
# load episode: 1049
# Episode  100, Average Score: 16.59, Best Average Score: 16.90 @ Episode   50, Best Score: 25 @ Episode   99
# <class 'config.AgentConfig'>: {'state_size': 37, 'action_size': 4, 'state_augment_size': 0, 'input_gray': False, 'n_episodes': 100, 'max_t_steps': 1000, 'replay_buf_size': 100000, 'min_replay_buf_size': 64, 'minibatch_size': 64, 'training_freq': 4, 'update_tgt_freq': 4, 'tau': 0.001, 'gamma': 0.99, 'eps_schedule': 'geometric', 'eps_start': 1.0, 'eps_end': 0.01, 'eps_decay': 0.995, 'seed': 0, 'ckpt_path': 'results/best_ma_chkpt_3.pth', 'replay_path': None}
# <class 'config.ModelConfig'>: {'learning_rate': 0.0001, 'weight_decay': 0, 'double_dqn': False, 'dueling_dqn': False, 'conv': <ConvType.CONV1D: (0,)>, 'input_dim': 37, 'output_dim': 4, 'seed': 0}
# FcModel(
#   (conv): Sequential(
#     (0): Linear(in_features=37, out_features=64, bias=True)
#     (1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Linear(in_features=64, out_features=64, bias=True)
#     (4): ReLU()
#   )
#   (fc3): Linear(in_features=64, out_features=4, bias=True)
# )
# FcModel(
#   (conv): Sequential(
#     (0): Linear(in_features=37, out_features=64, bias=True)
#     (1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Linear(in_features=64, out_features=64, bias=True)
#     (4): ReLU()
#   )
#   (fc3): Linear(in_features=64, out_features=4, bias=True)
# )
# load episode: 1019
# Episode  100, Average Score: 13.47, Best Average Score: 13.47 @ Episode  100, Best Score: 23 @ Episode   72

# %%
from utils import *
from workspace_utils import active_session
# %matplotlib inline

eps_decay = [0.995]
a_double = [True, False, True, False]
a_duel = [True, True, False, False]

with active_session():
    run_option('train', eps_decay, a_double, a_duel, 4, moving_avg_tgt=17.0, n_episodes=2000)
# Out:
# INFO:unityagents:
# 'Academy' started successfully!
# Unity Academy name: Academy
#         Number of Brains: 1
#         Number of External Brains : 1
#         Lesson number : 0
#         Reset Parameters :
#
# Unity brain name: BananaBrain
#         Number of Visual Observations (per agent): 0
#         Vector Observation space type: continuous
#         Vector Observation space size (per agent): 37
#         Number of stacked Vector Observation: 1
#         Vector Action space type: discrete
#         Vector Action space size (per agent): 4
#         Vector Action descriptions: , , ,
# <class 'config.AgentConfig'>: {'state_size': 37, 'action_size': 4, 'state_augment_size': 0, 'input_gray': False, 'n_episodes': 2000, 'max_t_steps': 1000, 'replay_buf_size': 100000, 'min_replay_buf_size': 256, 'minibatch_size': 64, 'training_freq': 4, 'update_tgt_freq': 4, 'tau': 0.001, 'gamma': 0.99, 'eps_schedule': 'geometric', 'eps_start': 1.0, 'eps_end': 0.01, 'eps_decay': 0.995, 'seed': 0, 'ckpt_path': None, 'replay_path': None}
# <class 'config.ModelConfig'>: {'learning_rate': 0.0001, 'weight_decay': 0, 'double_dqn': True, 'dueling_dqn': True, 'conv': <ConvType.CONV1D: (0,)>, 'input_dim': 37, 'output_dim': 4, 'seed': 0}
# FcModel(
#   (conv): Sequential(
#     (0): Linear(in_features=37, out_features=64, bias=False)
#     (1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Linear(in_features=64, out_features=64, bias=True)
#     (4): ReLU()
#   )
#   (fc3): Linear(in_features=64, out_features=4, bias=True)
#   (fc3_value): Linear(in_features=64, out_features=1, bias=True)
# )
# FcModel(
#   (conv): Sequential(
#     (0): Linear(in_features=37, out_features=64, bias=False)
#     (1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Linear(in_features=64, out_features=64, bias=True)
#     (4): ReLU()
#   )
#   (fc3): Linear(in_features=64, out_features=4, bias=True)
#   (fc3_value): Linear(in_features=64, out_features=1, bias=True)
# )
# Episode   50, Average Score:  0.32, Best Average Score:  0.67 @ Episode    3, Best Score:  3 @ Episode   27
# Episode  100, Average Score:  0.84, Best Average Score:  0.84 @ Episode  100, Best Score:  6 @ Episode   78
# Episode  150, Average Score:  2.07, Best Average Score:  2.07 @ Episode  150, Best Score:  7 @ Episode  145
# Episode  200, Average Score:  3.78, Best Average Score:  3.78 @ Episode  200, Best Score: 12 @ Episode  199
# Episode  250, Average Score:  5.84, Best Average Score:  5.84 @ Episode  250, Best Score: 13 @ Episode  223
# Episode  300, Average Score:  7.94, Best Average Score:  7.95 @ Episode  298, Best Score: 15 @ Episode  297
# Episode  350, Average Score:  9.74, Best Average Score:  9.74 @ Episode  350, Best Score: 17 @ Episode  323

# Out:
# INFO:unityagents:
# 'Academy' started successfully!
# Unity Academy name: Academy
#         Number of Brains: 1
#         Number of External Brains : 1
#         Lesson number : 0
#         Reset Parameters :
#
# Unity brain name: BananaBrain
#         Number of Visual Observations (per agent): 0
#         Vector Observation space type: continuous
#         Vector Observation space size (per agent): 37
#         Number of stacked Vector Observation: 1
#         Vector Action space type: discrete
#         Vector Action space size (per agent): 4
#         Vector Action descriptions: , , ,
# <class 'config.AgentConfig'>: {'state_size': 37, 'action_size': 4, 'state_augment_size': 0, 'input_gray': False, 'n_episodes': 100, 'max_t_steps': 1000, 'replay_buf_size': 100000, 'min_replay_buf_size': 256, 'minibatch_size': 64, 'training_freq': 4, 'update_tgt_freq': 4, 'tau': 0.001, 'gamma': 0.99, 'eps_schedule': 'geometric', 'eps_start': 1.0, 'eps_end': 0.01, 'eps_decay': 0.995, 'seed': 0, 'ckpt_path': 'results/best_ma_chkpt_4.pth', 'replay_path': None}
# <class 'config.ModelConfig'>: {'learning_rate': 0.0001, 'weight_decay': 0, 'double_dqn': True, 'dueling_dqn': True, 'conv': <ConvType.CONV1D: (0,)>, 'input_dim': 37, 'output_dim': 4, 'seed': 0}
# FcModel(
#   (conv): Sequential(
#     (0): Linear(in_features=37, out_features=64, bias=False)
#     (1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Linear(in_features=64, out_features=64, bias=True)
#     (4): ReLU()
#   )
#   (fc3): Linear(in_features=64, out_features=4, bias=True)
#   (fc3_value): Linear(in_features=64, out_features=1, bias=True)
# )
# FcModel(
#   (conv): Sequential(
#     (0): Linear(in_features=37, out_features=64, bias=False)
#     (1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Linear(in_features=64, out_features=64, bias=True)
#     (4): ReLU()
#   )
#   (fc3): Linear(in_features=64, out_features=4, bias=True)
#   (fc3_value): Linear(in_features=64, out_features=1, bias=True)
# )
# load episode: 912
# Episode  100, Average Score: 17.47, Best Average Score: 17.82 @ Episode   39, Best Score: 25 @ Episode   48
# <class 'config.AgentConfig'>: {'state_size': 37, 'action_size': 4, 'state_augment_size': 0, 'input_gray': False, 'n_episodes': 100, 'max_t_steps': 1000, 'replay_buf_size': 100000, 'min_replay_buf_size': 256, 'minibatch_size': 64, 'training_freq': 4, 'update_tgt_freq': 4, 'tau': 0.001, 'gamma': 0.99, 'eps_schedule': 'geometric', 'eps_start': 1.0, 'eps_end': 0.01, 'eps_decay': 0.995, 'seed': 0, 'ckpt_path': 'results/best_ma_chkpt_5.pth', 'replay_path': None}
# <class 'config.ModelConfig'>: {'learning_rate': 0.0001, 'weight_decay': 0, 'double_dqn': False, 'dueling_dqn': True, 'conv': <ConvType.CONV1D: (0,)>, 'input_dim': 37, 'output_dim': 4, 'seed': 0}
# FcModel(
#   (conv): Sequential(
#     (0): Linear(in_features=37, out_features=64, bias=False)
#     (1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Linear(in_features=64, out_features=64, bias=True)
#     (4): ReLU()
#   )
#   (fc3): Linear(in_features=64, out_features=4, bias=True)
#   (fc3_value): Linear(in_features=64, out_features=1, bias=True)
# )
# FcModel(
#   (conv): Sequential(
#     (0): Linear(in_features=37, out_features=64, bias=False)
#     (1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Linear(in_features=64, out_features=64, bias=True)
#     (4): ReLU()
#   )
#   (fc3): Linear(in_features=64, out_features=4, bias=True)
#   (fc3_value): Linear(in_features=64, out_features=1, bias=True)
# )
# load episode: 984
# Episode  100, Average Score: 16.80, Best Average Score: 21.00 @ Episode    6, Best Score: 25 @ Episode   51
# <class 'config.AgentConfig'>: {'state_size': 37, 'action_size': 4, 'state_augment_size': 0, 'input_gray': False, 'n_episodes': 100, 'max_t_steps': 1000, 'replay_buf_size': 100000, 'min_replay_buf_size': 256, 'minibatch_size': 64, 'training_freq': 4, 'update_tgt_freq': 4, 'tau': 0.001, 'gamma': 0.99, 'eps_schedule': 'geometric', 'eps_start': 1.0, 'eps_end': 0.01, 'eps_decay': 0.995, 'seed': 0, 'ckpt_path': 'results/best_ma_chkpt_6.pth', 'replay_path': None}
# <class 'config.ModelConfig'>: {'learning_rate': 0.0001, 'weight_decay': 0, 'double_dqn': True, 'dueling_dqn': False, 'conv': <ConvType.CONV1D: (0,)>, 'input_dim': 37, 'output_dim': 4, 'seed': 0}
# FcModel(
#   (conv): Sequential(
#     (0): Linear(in_features=37, out_features=64, bias=False)
#     (1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Linear(in_features=64, out_features=64, bias=True)
#     (4): ReLU()
#   )
#   (fc3): Linear(in_features=64, out_features=4, bias=True)
# )
# FcModel(
#   (conv): Sequential(
#     (0): Linear(in_features=37, out_features=64, bias=False)
#     (1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Linear(in_features=64, out_features=64, bias=True)
#     (4): ReLU()
#   )
#   (fc3): Linear(in_features=64, out_features=4, bias=True)
# )
# load episode: 1323
# Episode  100, Average Score: 16.84, Best Average Score: 18.90 @ Episode   10, Best Score: 25 @ Episode   32
# <class 'config.AgentConfig'>: {'state_size': 37, 'action_size': 4, 'state_augment_size': 0, 'input_gray': False, 'n_episodes': 100, 'max_t_steps': 1000, 'replay_buf_size': 100000, 'min_replay_buf_size': 256, 'minibatch_size': 64, 'training_freq': 4, 'update_tgt_freq': 4, 'tau': 0.001, 'gamma': 0.99, 'eps_schedule': 'geometric', 'eps_start': 1.0, 'eps_end': 0.01, 'eps_decay': 0.995, 'seed': 0, 'ckpt_path': 'results/best_ma_chkpt_7.pth', 'replay_path': None}
# <class 'config.ModelConfig'>: {'learning_rate': 0.0001, 'weight_decay': 0, 'double_dqn': False, 'dueling_dqn': False, 'conv': <ConvType.CONV1D: (0,)>, 'input_dim': 37, 'output_dim': 4, 'seed': 0}
# FcModel(
#   (conv): Sequential(
#     (0): Linear(in_features=37, out_features=64, bias=False)
#     (1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Linear(in_features=64, out_features=64, bias=True)
#     (4): ReLU()
#   )
#   (fc3): Linear(in_features=64, out_features=4, bias=True)
# )
# FcModel(
#   (conv): Sequential(
#     (0): Linear(in_features=37, out_features=64, bias=False)
#     (1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Linear(in_features=64, out_features=64, bias=True)
#     (4): ReLU()
#   )
#   (fc3): Linear(in_features=64, out_features=4, bias=True)
# )
# load episode: 1109
# Episode  100, Average Score: 16.71, Best Average Score: 18.00 @ Episode    1, Best Score: 25 @ Episode   80

# %%
from utils import *
from workspace_utils import active_session
# %matplotlib inline

eps_decay = [0.995]
a_double = [True, False, True, False]
a_duel = [True, True, False, False]
solved_episodes = [812, 884, 1223, 1009]

with active_session():
    display_scores('train', eps_decay, 17.0, a_double, a_duel, 4, 'results', solved_episodes)

# %%
from utils import *
from workspace_utils import active_session
# %matplotlib inline

eps_decay = [0.995]
a_double = [True, False, True, False]
a_duel = [True, True, False, False]

with active_session():
    display_scores('test', eps_decay, 17.0, a_double, a_duel, 4, 'results')

# %%
from torchviz import make_dot
import torch
import numpy as np
from model import Model
from config import ModelConfig

model_cfg = ModelConfig()
model_cfg.input_dim = 37
model_cfg.output_dim = 4

policy_dqn = Model(model_cfg, trainable=True)

model_cfg_ddqn = ModelConfig()
model_cfg_ddqn.input_dim = 37
model_cfg_ddqn.output_dim = 4
model_cfg_ddqn.dueling_dqn = True
policy_ddqn = Model(model_cfg_ddqn, trainable=True)

inp = np.expand_dims(np.zeros(model_cfg.input_dim), 0)
inp = np.repeat(inp, 32, axis=0)
inp = inp.astype(np.float32)
inp = policy_dqn.get_tensor(inp)
out_dqn = policy_dqn.net(inp)
out_ddqn = policy_ddqn.net(inp)

make_dot(out_dqn, params=dict(policy_dqn.net.named_parameters())).render("images/dqn", format="png")
make_dot(out_ddqn, params=dict(policy_ddqn.net.named_parameters())).render("images/duel_dqn", format="png")
# Out:
# FcModel(
#   (conv): Sequential(
#     (0): Linear(in_features=37, out_features=64, bias=True)
#     (1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Linear(in_features=64, out_features=64, bias=True)
#     (4): ReLU()
#   )
#   (fc3): Linear(in_features=64, out_features=4, bias=True)
# )
# FcModel(
#   (conv): Sequential(
#     (0): Linear(in_features=37, out_features=64, bias=True)
#     (1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Linear(in_features=64, out_features=64, bias=True)
#     (4): ReLU()
#   )
#   (fc3): Linear(in_features=64, out_features=4, bias=True)
#   (fc3_value): Linear(in_features=64, out_features=1, bias=True)
# )
# 'duel_dqn.png'
